# %%
import pandas as pd

# %%
import numpy as np

# %%
my_index=["USA","CANADA","MEXICO"]

# %%
my_data=[1776,1867,1821]

# %%
my_ser=pd.Series(my_data)

# %%
my_ser
# Out:
# 0    1776
# 1    1867
# 2    1821
# dtype: int64

# %%
type(my_ser)
# Out:
# pandas.core.series.Series

# %%
my_ser=pd.Series(my_data,my_index)

# %%
my_ser
# Out:
# USA       1776
# CANADA    1867
# MEXICO    1821
# dtype: int64

# %%
my_ser[0]
# Out:
# 1776

# %%
my_ser["USA"]
# Out:
# 1776

# %%
ages={'Sam':5,'Frank':10,'Spike':7}

# %%
pd.Series(ages)
# Out:
# Sam       5
# Frank    10
# Spike     7
# dtype: int64

# %%
q1={'Japan':80,'China':450,'India':200,'USA':250}
q2={'Brazil':100,'China':500,'India':210,'USA':260}

# %%
sales_q1=pd.Series(q1)

# %%
sales_q2=pd.Series(q2)

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_q2
# Out:
# Brazil    100
# China     500
# India     210
# USA       260
# dtype: int64

# %%
sales_q1[0:2]
# Out:
# Japan     80
# China    450
# dtype: int64

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
sales_q1['Japan']
# Out:
# 80

# %%
sales_q1['Japan']
# Out:
# 80

# %%
sales_q1+sales_q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
first_half=sales_q1.add(sales_q2,fill_value=0)

# %%
first_half.dtype
# Out:
# dtype('float64')

# %%
np.random.seed(101)
my_data=np.random.randint(0,101,(4,3))

# %%
my_data
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
my_index=['CA','NY','AZ','TX']

# %%
my_col=['Jan','Feb','Mar']

# %%
df=pd.DataFrame(data=my_data,index=my_index,columns=my_col,dtype=np.int64)

# %%
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int64
#  1   Feb     4 non-null      int64
#  2   Mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
ls
# Out:
#  Le volume dans le lecteur C s’appelle MEKA
#  Le numéro de série du volume est 2C07-31F3
#
#  Répertoire de C:\Users\Huawei\Documents\Formation DS UY1\Code\Pandas
#
# 04/03/2023  18:24    <DIR>          .
# 04/03/2023  18:24    <DIR>          ..
# 04/03/2023  12:53    <DIR>          .ipynb_checkpoints
# 04/03/2023  18:24            13 014 Pandas 1.ipynb
#                1 fichier(s)           13 014 octets
#                3 Rép(s)  33 797 881 856 octets libres

# %%
cd ..
# Out:
# C:\Users\Huawei\Documents\Formation DS UY1\Code

# %%
ls
# Out:
#  Le volume dans le lecteur C s’appelle MEKA
#  Le numéro de série du volume est 2C07-31F3
#
#  Répertoire de C:\Users\Huawei\Documents\Formation DS UY1\Code
#
# 04/03/2023  18:24    <DIR>          .
# 04/03/2023  08:22    <DIR>          ..
# 04/03/2023  12:52    <DIR>          .ipynb_checkpoints
# 01/03/2023  11:54    <DIR>          DataSet
# 04/03/2023  18:24    <DIR>          Numpy
# 04/03/2023  18:26    <DIR>          Pandas
# 02/03/2023  14:43    <DIR>          Python
# 02/03/2023  21:50             5 685 TP Python.zip
#                1 fichier(s)            5 685 octets
#                7 Rép(s)  33 801 834 496 octets libres

# %%
cd DataSet/
# Out:
# C:\Users\Huawei\Documents\Formation DS UY1\Code\DataSet

# %%
ls
# Out:
#  Le volume dans le lecteur C s’appelle MEKA
#  Le numéro de série du volume est 2C07-31F3
#
#  Répertoire de C:\Users\Huawei\Documents\Formation DS UY1\Code\DataSet
#
# 01/03/2023  11:54    <DIR>          .
# 04/03/2023  18:24    <DIR>          ..
# 01/03/2023  11:54    <DIR>          .ipynb_checkpoints
# 28/02/2023  16:42            17 511 2015.csv
# 28/02/2023  16:43            18 080 2016.csv
# 28/02/2023  16:44            30 137 2017.csv
# 28/02/2023  16:45             9 594 2018.csv
# 28/02/2023  16:45             9 607 2019.csv
# 28/02/2023  11:12           132 464 Data_NetFlix1.csv
# 28/02/2023  11:11           127 344 Data_NetFlix2.csv
#                7 fichier(s)          344 737 octets
#                3 Rép(s)  33 798 619 136 octets libres

# %%
data_set=pd.read_csv(r"C:\Users\Huawei\Documents\Formation DS UY1\Code\DataSet\")

# %%
data_set
# Out:
#        id first_name     last_name  age  gender                        email  \
# 0       1     Jaclyn    Duchasteau   66  Female         jduchasteau0@163.com
# 1       2      Rubia      Lodemann   74  Female    rlodemann1@eventbrite.com
# 2       3   Estrella         Etter   36  Female      eetter2@themeforest.net
# 3       4     Wendie          Coat   44  Female          wcoat3@edublogs.org
# 4       5    Barclay       Morrish   70    Male             bmorrish4@a8.net
# ..    ...        ...           ...  ...     ...                          ...
# 995   996   Bernelle  Chomiszewski   76  Female      bchomiszewskirn@ask.com
# 996   997      Fiona          Enns   73  Female         fennsro@geocities.jp
# 997   998    Bastien      McEnhill   32    Male  bmcenhillrp@kickstarter.com
# 998   999      Flint          Dash   54    Male     fdashrq@surveymonkey.com
# 999  1000        Mel   MacGettigen   37  Female     mmacgettigenrr@hexun.com
#
# ...

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1000 non-null   int64
#  1   first_name    1000 non-null   object
#  2   last_name     1000 non-null   object
#  3   age           1000 non-null   int64
#  4   gender        1000 non-null   object
#  5   email         1000 non-null   object
#  6   ip_address    1000 non-null   object
#  7   amount spent  1000 non-null   int64
#  8   Movie Genres  1000 non-null   object
#  9   Movie Title   1000 non-null   object
#  10  Country       1000 non-null   object
#  11  City          1000 non-null   object
#  12  Year          1000 non-null   int64
# dtypes: int64(4), object(9)
# memory usage: 101.7+ KB

# %%
 data_set.head()
# Out:
#    id first_name   last_name  age  gender                      email  \
# 0   1     Jaclyn  Duchasteau   66  Female       jduchasteau0@163.com
# 1   2      Rubia    Lodemann   74  Female  rlodemann1@eventbrite.com
# 2   3   Estrella       Etter   36  Female    eetter2@themeforest.net
# 3   4     Wendie        Coat   44  Female        wcoat3@edublogs.org
# 4   5    Barclay     Morrish   70    Male           bmorrish4@a8.net
#
#         ip_address  amount spent                Movie Genres  \
# 0     23.4.207.109         11495  Adventure|Animation|Comedy
# 1   88.228.208.216         28144                    Thriller
# 2  149.174.168.172         79891            Action|Drama|War
# 3    55.108.153.60         98806                      Horror
# 4  172.209.236.180         89451       Adventure|Documentary
#
#                              Movie Title       Country       City  Year
# 0                            Croods, The         Japan      Izumi  2015
# ...

# %%
data_set['amount spent']
# Out:
# 0      11495
# 1      28144
# 2      79891
# 3      98806
# 4      89451
#        ...
# 995    45661
# 996    27454
# 997    34143
# 998    52176
# 999    61859
# Name: amount spent, Length: 1000, dtype: int64

# %%
type(data_set['amount spent'])
# Out:
# pandas.core.series.Series

# %%
data_set[['gender','age']]
# Out:
#      gender  age
# 0    Female   66
# 1    Female   74
# 2    Female   36
# 3    Female   44
# 4      Male   70
# ..      ...  ...
# 995  Female   76
# 996  Female   73
# 997    Male   32
# 998    Male   54
# 999  Female   37
#
# [1000 rows x 2 columns]

# %%
ls
# Out:
#  Le volume dans le lecteur C s’appelle MEKA
#  Le numéro de série du volume est 2C07-31F3
#
#  Répertoire de C:\Users\Huawei\Documents\Formation DS UY1\Code\DataSet
#
# 01/03/2023  11:54    <DIR>          .
# 04/03/2023  18:24    <DIR>          ..
# 01/03/2023  11:54    <DIR>          .ipynb_checkpoints
# 28/02/2023  16:42            17 511 2015.csv
# 28/02/2023  16:43            18 080 2016.csv
# 28/02/2023  16:44            30 137 2017.csv
# 28/02/2023  16:45             9 594 2018.csv
# 28/02/2023  16:45             9 607 2019.csv
# 28/02/2023  11:12           132 464 Data_NetFlix1.csv
# 28/02/2023  11:11           127 344 Data_NetFlix2.csv
#                7 fichier(s)          344 737 octets
#                3 Rép(s)  33 793 171 456 octets libres

# %%
pwd
# Out:
# 'C:\\Users\\Huawei\\Documents\\Formation DS UY1\\Code\\DataSet'

# %%
df2=pd.read_csv('C:\\Users\\Huawei\\Documents\\Formation DS UY1\\Code\\DataSet\\2015.csv')

# %%
df2
# Out:
#          Country                           Region  Year  Happiness Rank  \
# 0    Switzerland                   Western Europe  2015               1
# 1        Iceland                   Western Europe  2015               2
# 2        Denmark                   Western Europe  2015               3
# 3         Norway                   Western Europe  2015               4
# 4         Canada                    North America  2015               5
# ..           ...                              ...   ...             ...
# 153       Rwanda               Sub-Saharan Africa  2015             154
# 154        Benin               Sub-Saharan Africa  2015             155
# 155        Syria  Middle East and Northern Africa  2015             156
# 156      Burundi               Sub-Saharan Africa  2015             157
# 157         Togo               Sub-Saharan Africa  2015             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %%
df2['Ecart Score-Erreur']=(df2['Happiness Score']-df2['Standard Error'])

# %%
df2.head()
# Out:
#        Country          Region  Year  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe  2015               1            7.587
# 1      Iceland  Western Europe  2015               2            7.561
# 2      Denmark  Western Europe  2015               3            7.527
# 3       Norway  Western Europe  2015               4            7.522
# 4       Canada   North America  2015               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df2['Ecart Score-Erreur']=np.round((df2['Happiness Score']-df2['Standard Error']),2)

# %%
df2.head()
# Out:
#        Country          Region  Year  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe  2015               1            7.587
# 1      Iceland  Western Europe  2015               2            7.561
# 2      Denmark  Western Europe  2015               3            7.527
# 3       Norway  Western Europe  2015               4            7.522
# 4       Canada   North America  2015               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df2=df2.drop('Ecart Score-Erreur',axis=1)

# %%
df2
# Out:
#          Country                           Region  Year  Happiness Rank  \
# 0    Switzerland                   Western Europe  2015               1
# 1        Iceland                   Western Europe  2015               2
# 2        Denmark                   Western Europe  2015               3
# 3         Norway                   Western Europe  2015               4
# 4         Canada                    North America  2015               5
# ..           ...                              ...   ...             ...
# 153       Rwanda               Sub-Saharan Africa  2015             154
# 154        Benin               Sub-Saharan Africa  2015             155
# 155        Syria  Middle East and Northern Africa  2015             156
# 156      Burundi               Sub-Saharan Africa  2015             157
# 157         Togo               Sub-Saharan Africa  2015             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %%
df2.head()
# Out:
#        Country          Region  Year  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe  2015               1            7.587
# 1      Iceland  Western Europe  2015               2            7.561
# 2      Denmark  Western Europe  2015               3            7.527
# 3       Norway  Western Europe  2015               4            7.522
# 4       Canada   North America  2015               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=158, step=1)

# %%
data_set.set_index('id')
# Out:
#      first_name     last_name  age  gender                        email  \
# id
# 1        Jaclyn    Duchasteau   66  Female         jduchasteau0@163.com
# 2         Rubia      Lodemann   74  Female    rlodemann1@eventbrite.com
# 3      Estrella         Etter   36  Female      eetter2@themeforest.net
# 4        Wendie          Coat   44  Female          wcoat3@edublogs.org
# 5       Barclay       Morrish   70    Male             bmorrish4@a8.net
# ...         ...           ...  ...     ...                          ...
# 996    Bernelle  Chomiszewski   76  Female      bchomiszewskirn@ask.com
# 997       Fiona          Enns   73  Female         fennsro@geocities.jp
# 998     Bastien      McEnhill   32    Male  bmcenhillrp@kickstarter.com
# 999       Flint          Dash   54    Male     fdashrq@surveymonkey.com
# 1000        Mel   MacGettigen   37  Female     mmacgettigenrr@hexun.com
#
#            ip_address  amount spent                Movie Genres  \
# id
# ...
